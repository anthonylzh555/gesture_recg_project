# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution3D, MaxPooling3D

from keras.optimizers import SGD, RMSprop
from keras.utils import np_utils, generic_utils
from keras.callbacks import EarlyStopping, ModelCheckpoint

#import theano
import os
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
from sklearn.cross_validation import train_test_split
from sklearn import cross_validation
from sklearn import preprocessing

# %%
# image specification
img_rows,img_cols = 112,112
img_depth = 16
X_tr = []

# %%
img = cv2.imread("action_data/Hand/thumbup/Aerial-L-L-ThumbUp/Aerial-L-L-ThumbUp_035.jpg")

print(img.shape)
print("plt.imshow(img)")
img = cv2.resize(img, (112,112))
plt.imshow(img)
# Out:
# (960, 540, 3)
# plt.imshow(img)

# %% [markdown]
# ## import thumbup

# %%
from tqdm import tqdm
train_folder_path = os.path.join(os.getcwd(), "action_data/Hand/thumbup")
train_folder_list = sorted(os.listdir(train_folder_path))

for dicname in tqdm(train_folder_list):
    list_path = os.path.join(train_folder_path, dicname)
    frames = []
    i=0
    for img in sorted(os.listdir(list_path)):
        if i < img_depth:
            img_path = os.path.join(list_path, img)
            frame = cv2.imread(os.path.join(list_path, img))
            frame = cv2.resize(frame,(img_rows,img_cols))
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            frames.append(gray)
            i = i+1
        else:
            break

    input=np.array(frames)
    #print (input.shape)
    ipt = np.rollaxis(np.rollaxis(input,2,0),2,0)
    #ipt=np.rollaxis(ipt,3,0)
    #print (ipt.shape)
    #print("__")
    X_tr.append(ipt)
    
print (ipt.shape)
num_samples = len(X_tr)
print(num_samples)
# Out:
# 100%|██████████| 116/116 [00:56<00:00,  2.15it/s]
# (112, 112, 16)
# 116

# %% [markdown]
# ## import stop

# %%
train_folder_path = os.path.join(os.getcwd(), "action_data/Hand/stop")
train_folder_list = sorted(os.listdir(train_folder_path))

for dicname in tqdm(train_folder_list):
    list_path = os.path.join(train_folder_path, dicname)
    frames = []
    i=0
    for img in sorted(os.listdir(list_path)):
        if i < img_depth:
            img_path = os.path.join(list_path, img)
            frame = cv2.imread(os.path.join(list_path, img))
            frame = cv2.resize(frame,(img_rows,img_cols))
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            frames.append(gray)
            i = i+1
        else:
            break

    input=np.array(frames)
    #print (input.shape)
    ipt = np.rollaxis(np.rollaxis(input,2,0),2,0)
    #ipt=np.rollaxis(ipt,3,0)
    #print (ipt.shape)
    #print("__")
    X_tr.append(ipt)
    
print (ipt.shape)
num_samples = len(X_tr)
print(num_samples)
# Out:
# 100%|██████████| 198/198 [01:34<00:00,  5.85it/s]
# (112, 112, 16)
# 314

# %% [markdown]
# ## import clockwise

# %%
train_folder_path = os.path.join(os.getcwd(), "action_data/Hand/clockwise")
train_folder_list = sorted(os.listdir(train_folder_path))

for dicname in tqdm(train_folder_list):
    list_path = os.path.join(train_folder_path, dicname)
    frames = []
    i=0
    for img in sorted(os.listdir(list_path)):
        if i < img_depth:
            img_path = os.path.join(list_path, img)
            frame = cv2.imread(os.path.join(list_path, img))
            frame = cv2.resize(frame,(img_rows,img_cols))
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            frames.append(gray)
            i = i+1
        else:
            break

    input=np.array(frames)
    #print (input.shape)
    ipt = np.rollaxis(np.rollaxis(input,2,0),2,0)
    #ipt=np.rollaxis(ipt,3,0)
    #print (ipt.shape)
    #print("__")
    X_tr.append(ipt)
    
print (ipt.shape)
num_samples = len(X_tr)
print(num_samples)
# Out:
# 100%|██████████| 116/116 [00:55<00:00,  1.42it/s]
# (112, 112, 16)
# 430

# %% [markdown]
# ## import counterclockwise

# %%
train_folder_path = os.path.join(os.getcwd(), "action_data/Hand/counterclockwise")
train_folder_list = sorted(os.listdir(train_folder_path))

for dicname in tqdm(train_folder_list):
    list_path = os.path.join(train_folder_path, dicname)
    frames = []
    i=0
    for img in sorted(os.listdir(list_path)):
        if i < img_depth:
            img_path = os.path.join(list_path, img)
            frame = cv2.imread(os.path.join(list_path, img))
            frame = cv2.resize(frame,(img_rows,img_cols))
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            frames.append(gray)
            i = i+1
        else:
            break

    input=np.array(frames)
    #print (input.shape)
    ipt = np.rollaxis(np.rollaxis(input,2,0),2,0)
    #ipt=np.rollaxis(ipt,3,0)
    #print (ipt.shape)
    #print("__")
    X_tr.append(ipt)
    
print (ipt.shape)
num_samples = len(X_tr)
print(num_samples)
# Out:
# 100%|██████████| 124/124 [00:55<00:00,  1.39it/s]
# (112, 112, 16)
# 554

# %% [markdown]
# ## import updown

# %%
train_folder_path = os.path.join(os.getcwd(), "action_data/Hand/UpDown")
train_folder_list = sorted(os.listdir(train_folder_path))

for dicname in tqdm(train_folder_list):
    list_path = os.path.join(train_folder_path, dicname)
    frames = []
    i=0
    for img in sorted(os.listdir(list_path)):
        if i < img_depth:
            img_path = os.path.join(list_path, img)
            frame = cv2.imread(os.path.join(list_path, img))
            frame = cv2.resize(frame,(img_rows,img_cols))
            gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
            frames.append(gray)
            i = i+1
        else:
            break

    input=np.array(frames)
    #print (input.shape)
    ipt = np.rollaxis(np.rollaxis(input,2,0),2,0)
    #ipt=np.rollaxis(ipt,3,0)
    #print (ipt.shape)
    #print("__")
    X_tr.append(ipt)
    
print (ipt.shape)
num_samples = len(X_tr)
print(num_samples)
# Out:
# 100%|██████████| 187/187 [01:12<00:00,  2.89it/s]
# (112, 112, 16)
# 741

# %%
X_tr_array = np.array(X_tr)   # convert the frames read into array

num_samples = len(X_tr_array) 
print (num_samples)
# Out:
# 741

# %% [markdown]
# ## label DATA

# %%
label=np.ones((num_samples,),dtype = int)
label[0:116]= 0                   #thumbup
label[117:314] = 1                #stop
label[315:430] = 2                #clockwise
label[431:554] = 3                #counterclockwise
label[555:741]= 4                 #updown

train_data = [X_tr_array,label]

(X_train, y_train) = (train_data[0],train_data[1])
#print(train_data)
print('X_Train shape:', X_train.shape)
# Out:
# X_Train shape: (741, 112, 112, 16)

# %%
train_set = np.zeros((num_samples, 1, img_rows,img_cols,img_depth))
#train_set = X_train
for h in range(num_samples):
    train_set[h][0][:][:][:][:]=X_train[h,:,:,:]

# %%
#patch_size = 16    # img_depth or number of frames used for each video

print(X_train.shape,"X_train shapes")
print(train_set.shape, 'train samples')
# Out:
# (741, 112, 112, 16) X_train shapes
# (741, 1, 112, 112, 16) train samples

# %% [markdown]
# ## CNN Training parameters

# %%
nb_classes = 5

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)
#print(Y_train)
# Pre-processing
train_set = train_set.astype('float32')
train_set -= np.mean(train_set)
train_set /= np.max(train_set)

# %% [markdown]
# # Define Model

# %%
model = Sequential()

model.add(Convolution3D(32, (5,5,5), input_shape=(1, 112, 112, 16), activation='relu',data_format='channels_first'))

model.add(MaxPooling3D(pool_size=(3,3,3),data_format="channels_first"))
model.add(Dropout(0.5))

#fully connected layer
model.add(Flatten())
model.add(Dense(128, kernel_initializer='normal', activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))

print(model.summary())
opt = keras.optimizers.Adam(lr=0.001)
#opt = keras.optimizers.rmsprop(lr=0.0001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt ,metrics=['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_6 (Conv3D)            (None, 32, 108, 108, 12)  4032
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 32, 36, 36, 4)     0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32, 36, 36, 4)     0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 165888)            0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               21233792
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 21,238,469
# Trainable params: 21,238,469
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## split data

# %%
X_train_new, X_val_new, y_train_new,y_val_new =  train_test_split(train_set, Y_train, test_size=0.2, random_state=4)

# %%
batch_size = 20
nb_epoch = 100

# %%
# Use ModelCheckpoint to save model and weights
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'C3D_model_test1_gray.h5'

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
checkpoint = ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)

# earlystop
earlystop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)


hist = model.fit(X_train_new, y_train_new, 
                 validation_data=(X_val_new,y_val_new),
                 batch_size=batch_size,
                 epochs = nb_epoch, 
                 shuffle=True, 
                 callbacks=[checkpoint, earlystop])
# Out:
# Train on 592 samples, validate on 149 samples
# Epoch 1/100
# 592/592 [==============================] - 4s 7ms/step - loss: 8.9961 - acc: 0.2179 - val_loss: 3.9766 - val_acc: 0.2282
#
# Epoch 00001: val_loss improved from inf to 3.97657, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 2/100
# 592/592 [==============================] - 3s 5ms/step - loss: 2.6669 - acc: 0.2382 - val_loss: 1.5966 - val_acc: 0.2819
#
# Epoch 00002: val_loss improved from 3.97657 to 1.59665, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 3/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.6075 - acc: 0.2416 - val_loss: 1.6162 - val_acc: 0.2416
#
# Epoch 00003: val_loss did not improve from 1.59665
# Epoch 4/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.6180 - acc: 0.2331 - val_loss: 1.5905 - val_acc: 0.3020
#
# Epoch 00004: val_loss improved from 1.59665 to 1.59048, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 5/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.6076 - acc: 0.2635 - val_loss: 1.6000 - val_acc: 0.2953
#
# Epoch 00005: val_loss did not improve from 1.59048
# Epoch 6/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.6047 - acc: 0.2686 - val_loss: 1.5960 - val_acc: 0.2886
#
# Epoch 00006: val_loss did not improve from 1.59048
# Epoch 7/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.6226 - acc: 0.2720 - val_loss: 1.5730 - val_acc: 0.2953
#
# Epoch 00007: val_loss improved from 1.59048 to 1.57295, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 8/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.5745 - acc: 0.2652 - val_loss: 1.5539 - val_acc: 0.2953
#
# Epoch 00008: val_loss improved from 1.57295 to 1.55386, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 9/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.5586 - acc: 0.2652 - val_loss: 1.5160 - val_acc: 0.2953
#
# Epoch 00009: val_loss improved from 1.55386 to 1.51604, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 10/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.5300 - acc: 0.2703 - val_loss: 1.4951 - val_acc: 0.2617
#
# Epoch 00010: val_loss improved from 1.51604 to 1.49507, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 11/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.5012 - acc: 0.2821 - val_loss: 1.4696 - val_acc: 0.2953
#
# Epoch 00011: val_loss improved from 1.49507 to 1.46958, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 12/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.4797 - acc: 0.2686 - val_loss: 1.4670 - val_acc: 0.2953
#
# Epoch 00012: val_loss improved from 1.46958 to 1.46696, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 13/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.4374 - acc: 0.2753 - val_loss: 1.4676 - val_acc: 0.2819
#
# Epoch 00013: val_loss did not improve from 1.46696
# Epoch 14/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.4344 - acc: 0.2618 - val_loss: 1.3963 - val_acc: 0.2953
#
# Epoch 00014: val_loss improved from 1.46696 to 1.39629, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 15/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.4055 - acc: 0.2686 - val_loss: 1.3827 - val_acc: 0.3087
#
# Epoch 00015: val_loss improved from 1.39629 to 1.38267, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 16/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.4083 - acc: 0.2669 - val_loss: 1.3806 - val_acc: 0.3154
#
# Epoch 00016: val_loss improved from 1.38267 to 1.38055, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 17/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.4034 - acc: 0.2601 - val_loss: 1.3653 - val_acc: 0.3020
#
# Epoch 00017: val_loss improved from 1.38055 to 1.36535, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 18/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.3461 - acc: 0.3007 - val_loss: 1.3503 - val_acc: 0.3557
#
# Epoch 00018: val_loss improved from 1.36535 to 1.35033, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 19/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.3684 - acc: 0.3395 - val_loss: 1.3183 - val_acc: 0.3826
#
# Epoch 00019: val_loss improved from 1.35033 to 1.31829, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 20/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.3194 - acc: 0.3581 - val_loss: 1.2903 - val_acc: 0.3557
#
# Epoch 00020: val_loss improved from 1.31829 to 1.29030, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 21/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.3031 - acc: 0.3632 - val_loss: 1.3359 - val_acc: 0.3758
#
# Epoch 00021: val_loss did not improve from 1.29030
# Epoch 22/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.3367 - acc: 0.3429 - val_loss: 1.3082 - val_acc: 0.4027
#
# Epoch 00022: val_loss did not improve from 1.29030
# Epoch 23/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.2857 - acc: 0.3986 - val_loss: 1.2713 - val_acc: 0.4027
#
# Epoch 00023: val_loss improved from 1.29030 to 1.27131, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 24/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.2824 - acc: 0.3581 - val_loss: 1.2410 - val_acc: 0.3758
#
# Epoch 00024: val_loss improved from 1.27131 to 1.24101, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 25/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.2898 - acc: 0.3480 - val_loss: 1.1666 - val_acc: 0.4228
#
# Epoch 00025: val_loss improved from 1.24101 to 1.16657, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 26/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.2801 - acc: 0.3260 - val_loss: 1.1799 - val_acc: 0.4094
#
# Epoch 00026: val_loss did not improve from 1.16657
# Epoch 27/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.2522 - acc: 0.3784 - val_loss: 1.1778 - val_acc: 0.4295
#
# Epoch 00027: val_loss did not improve from 1.16657
# Epoch 28/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.2240 - acc: 0.4003 - val_loss: 1.1735 - val_acc: 0.3691
#
# Epoch 00028: val_loss did not improve from 1.16657
# Epoch 29/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.1789 - acc: 0.3970 - val_loss: 1.1666 - val_acc: 0.4362
#
# Epoch 00029: val_loss did not improve from 1.16657
# Epoch 30/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.2034 - acc: 0.4358 - val_loss: 1.0499 - val_acc: 0.5101
#
# Epoch 00030: val_loss improved from 1.16657 to 1.04988, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 31/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.1735 - acc: 0.4257 - val_loss: 1.0338 - val_acc: 0.5369
#
# Epoch 00031: val_loss improved from 1.04988 to 1.03382, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 32/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.1558 - acc: 0.4443 - val_loss: 1.1457 - val_acc: 0.5302
#
# Epoch 00032: val_loss did not improve from 1.03382
# Epoch 33/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.2551 - acc: 0.3953 - val_loss: 1.0941 - val_acc: 0.4430
#
# Epoch 00033: val_loss did not improve from 1.03382
# Epoch 34/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.1183 - acc: 0.4341 - val_loss: 1.0349 - val_acc: 0.5302
#
# Epoch 00034: val_loss did not improve from 1.03382
# Epoch 35/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.0731 - acc: 0.4679 - val_loss: 0.9675 - val_acc: 0.6174
#
# Epoch 00035: val_loss improved from 1.03382 to 0.96754, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 36/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.0457 - acc: 0.4696 - val_loss: 1.0645 - val_acc: 0.5973
#
# Epoch 00036: val_loss did not improve from 0.96754
# Epoch 37/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.0429 - acc: 0.4375 - val_loss: 1.2070 - val_acc: 0.4765
#
# Epoch 00037: val_loss did not improve from 0.96754
# Epoch 38/100
# 592/592 [==============================] - 3s 4ms/step - loss: 1.0639 - acc: 0.5051 - val_loss: 0.9548 - val_acc: 0.6174
#
# Epoch 00038: val_loss improved from 0.96754 to 0.95482, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 39/100
# 592/592 [==============================] - 3s 5ms/step - loss: 1.0428 - acc: 0.4780 - val_loss: 0.9989 - val_acc: 0.5705
#
# Epoch 00039: val_loss did not improve from 0.95482
# Epoch 40/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.9539 - acc: 0.5372 - val_loss: 0.9067 - val_acc: 0.5638
#
# Epoch 00040: val_loss improved from 0.95482 to 0.90669, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 41/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.9644 - acc: 0.5203 - val_loss: 0.9998 - val_acc: 0.5638
#
# Epoch 00041: val_loss did not improve from 0.90669
# Epoch 42/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.9709 - acc: 0.5355 - val_loss: 0.8989 - val_acc: 0.5906
#
# Epoch 00042: val_loss improved from 0.90669 to 0.89892, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 43/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.9931 - acc: 0.4932 - val_loss: 0.9743 - val_acc: 0.5302
#
# Epoch 00043: val_loss did not improve from 0.89892
# Epoch 44/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.9362 - acc: 0.5287 - val_loss: 0.8070 - val_acc: 0.5973
#
# Epoch 00044: val_loss improved from 0.89892 to 0.80702, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 45/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.9614 - acc: 0.5490 - val_loss: 0.8681 - val_acc: 0.6174
#
# Epoch 00045: val_loss did not improve from 0.80702
# Epoch 46/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.8874 - acc: 0.5760 - val_loss: 1.0242 - val_acc: 0.5570
#
# Epoch 00046: val_loss did not improve from 0.80702
# Epoch 47/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.9603 - acc: 0.5017 - val_loss: 0.8434 - val_acc: 0.5973
#
# Epoch 00047: val_loss did not improve from 0.80702
# Epoch 48/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.8739 - acc: 0.6047 - val_loss: 1.0137 - val_acc: 0.5973
#
# Epoch 00048: val_loss did not improve from 0.80702
# Epoch 49/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.8647 - acc: 0.5541 - val_loss: 0.9133 - val_acc: 0.5772
#
# Epoch 00049: val_loss did not improve from 0.80702
# Epoch 50/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.9716 - acc: 0.5270 - val_loss: 0.7927 - val_acc: 0.6309
#
# Epoch 00050: val_loss improved from 0.80702 to 0.79268, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 51/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.8597 - acc: 0.5895 - val_loss: 0.9098 - val_acc: 0.6376
#
# Epoch 00051: val_loss did not improve from 0.79268
# Epoch 52/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.8804 - acc: 0.5845 - val_loss: 0.8581 - val_acc: 0.6174
#
# Epoch 00052: val_loss did not improve from 0.79268
# Epoch 53/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.8595 - acc: 0.5557 - val_loss: 0.7774 - val_acc: 0.6376
#
# Epoch 00053: val_loss improved from 0.79268 to 0.77737, saving model to /home/jovyan/project/saved_models/C3D_model_test1.h5
# Epoch 54/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.8777 - acc: 0.5743 - val_loss: 0.8302 - val_acc: 0.6174
#
# Epoch 00054: val_loss did not improve from 0.77737
# Epoch 55/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7864 - acc: 0.5845 - val_loss: 0.9670 - val_acc: 0.6040
#
# Epoch 00055: val_loss did not improve from 0.77737
# Epoch 56/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.7479 - acc: 0.5845 - val_loss: 0.8179 - val_acc: 0.6174
#
# Epoch 00056: val_loss did not improve from 0.77737
# Epoch 57/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7681 - acc: 0.5980 - val_loss: 0.9085 - val_acc: 0.6174
#
# Epoch 00057: val_loss did not improve from 0.77737
# Epoch 58/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.7819 - acc: 0.6030 - val_loss: 0.7790 - val_acc: 0.6376
#
# Epoch 00058: val_loss did not improve from 0.77737
# Epoch 59/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7824 - acc: 0.6267 - val_loss: 0.9534 - val_acc: 0.5973
#
# Epoch 00059: val_loss did not improve from 0.77737
# Epoch 60/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7667 - acc: 0.6166 - val_loss: 0.8746 - val_acc: 0.6644
#
# Epoch 00060: val_loss did not improve from 0.77737
# Epoch 61/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7062 - acc: 0.6453 - val_loss: 0.8794 - val_acc: 0.6174
#
# Epoch 00061: val_loss did not improve from 0.77737
# Epoch 62/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7469 - acc: 0.6098 - val_loss: 0.9626 - val_acc: 0.5772
#
# Epoch 00062: val_loss did not improve from 0.77737
# Epoch 63/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7521 - acc: 0.5946 - val_loss: 0.9567 - val_acc: 0.6040
#
# Epoch 00063: val_loss did not improve from 0.77737
# Epoch 64/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7676 - acc: 0.6064 - val_loss: 1.0046 - val_acc: 0.5906
#
# Epoch 00064: val_loss did not improve from 0.77737
# Epoch 65/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7163 - acc: 0.6166 - val_loss: 0.9481 - val_acc: 0.5839
#
# Epoch 00065: val_loss did not improve from 0.77737
# Epoch 66/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7059 - acc: 0.6318 - val_loss: 0.9898 - val_acc: 0.5705
#
# Epoch 00066: val_loss did not improve from 0.77737
# Epoch 67/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7180 - acc: 0.6385 - val_loss: 1.1864 - val_acc: 0.5302
#
# Epoch 00067: val_loss did not improve from 0.77737
# Epoch 68/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.6968 - acc: 0.6351 - val_loss: 0.9169 - val_acc: 0.6510
#
# Epoch 00068: val_loss did not improve from 0.77737
# Epoch 69/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7750 - acc: 0.6030 - val_loss: 0.9988 - val_acc: 0.6040
#
# Epoch 00069: val_loss did not improve from 0.77737
# Epoch 70/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.6579 - acc: 0.6385 - val_loss: 1.0541 - val_acc: 0.6040
#
# Epoch 00070: val_loss did not improve from 0.77737
# Epoch 71/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.7718 - acc: 0.5963 - val_loss: 0.8687 - val_acc: 0.5436
#
# Epoch 00071: val_loss did not improve from 0.77737
# Epoch 72/100
# 592/592 [==============================] - 3s 5ms/step - loss: 0.7139 - acc: 0.6503 - val_loss: 1.0743 - val_acc: 0.5705
#
# Epoch 00072: val_loss did not improve from 0.77737
# Epoch 73/100
# 592/592 [==============================] - 3s 4ms/step - loss: 0.7865 - acc: 0.6166 - val_loss: 1.1483 - val_acc: 0.5839
#
# Epoch 00073: val_loss did not improve from 0.77737
# Epoch 00073: early stopping

# %%
# loading our save model
print("Loading trained model")
model = load_model(model_path)
# Out:
# Loading trained model

# %%
score = model.evaluate(X_val_new, y_val_new, batch_size=batch_size)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# 149/149 [==============================] - 0s 3ms/step
# Test score: 0.7773701972609398
# Test accuracy: 0.637583886216951

# %%
train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['acc']
val_acc=hist.history['val_acc']

plt.figure(1,figsize=(7,5))
plt.plot(train_loss, label="training_loss")
plt.plot(val_loss, label="validation_loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.title("Learning Curve")
plt.legend(loc='best')
print (plt.style.available) # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

plt.figure(2,figsize=(7,5))
plt.plot(train_acc, label="training_acc")
plt.plot(val_acc, label="validation_acc")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.title("Learning Curve")
plt.legend(loc='best')
print (plt.style.available) # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])
# Out:
# ['seaborn-notebook', 'classic', 'seaborn-pastel', 'seaborn-white', 'seaborn-talk', 'bmh', 'seaborn', 'Solarize_Light2', 'seaborn-bright', 'seaborn-ticks', 'seaborn-paper', 'seaborn-muted', 'seaborn-darkgrid', 'fivethirtyeight', 'seaborn-dark-palette', 'seaborn-dark', 'grayscale', 'dark_background', 'seaborn-colorblind', 'seaborn-deep', '_classic_test', 'tableau-colorblind10', 'ggplot', 'seaborn-whitegrid', 'seaborn-poster', 'fast']
# ['seaborn-notebook', 'classic', 'seaborn-pastel', 'seaborn-white', 'seaborn-talk', 'bmh', 'seaborn', 'Solarize_Light2', 'seaborn-bright', 'seaborn-ticks', 'seaborn-paper', 'seaborn-muted', 'seaborn-darkgrid', 'fivethirtyeight', 'seaborn-dark-palette', 'seaborn-dark', 'grayscale', 'dark_background', 'seaborn-colorblind', 'seaborn-deep', '_classic_test', 'tableau-colorblind10', 'ggplot', 'seaborn-whitegrid', 'seaborn-poster', 'fast']

# %%
import itertools
def confusion_matrix_plot(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
from sklearn import svm, datasets
from sklearn.metrics import confusion_matrix

# %%
#model.fit(X_train_new, y_train_new)
#y_pred = model.predict(X_val_new)
y_pred = model.predict(train_set)

#a = np.argmax(y_val_new, axis=1)
a = np.argmax(Y_train, axis=1)
b = np.argmax(y_pred, axis=1)
print("benchmark : ",a)
print("predict : ",b)

# %%
met = confusion_matrix(a, b)
np.set_printoptions(precision=2)
print(met)
# Out:
# [[115   0   1   0   0]
#  [  4 185   0   1  11]
#  [  2   0   7 104   2]
#  [  2   0   9 111   1]
#  [  4  45   0   2 135]]

# %%
confusion_matrix_plot(met, normalize=True, classes=['thumbup', 'stop', 'clockwise', 'counterclockwise', 'updown'])
# Out:
# Normalized confusion matrix
# [[0.99 0.   0.01 0.   0.  ]
#  [0.02 0.92 0.   0.   0.05]
#  [0.02 0.   0.06 0.9  0.02]
#  [0.02 0.   0.07 0.9  0.01]
#  [0.02 0.24 0.   0.01 0.73]]
